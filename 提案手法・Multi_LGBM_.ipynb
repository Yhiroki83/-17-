# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy.stats import pearsonr
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from tqdm.notebook import tqdm
import random
import warnings
import gc
import time
from IPython.core.display import Image
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 100)

# %%
# !pip uninstall --yes lightgbm && pip install --install-option=--gpu lightgbm

# %%
for_train2 = pd.read_csv("./data/for_train.csv")
for_test2 = pd.read_csv("./data/for_test.csv")
df_missing = pd.read_csv("./data/df_missing.csv")
unique_id = for_train2["id"].astype(int).unique()

# %%
import lightgbm as lgb
import joblib
from sklearn.metrics import r2_score
from sklearn.model_selection import StratifiedKFold

folds = 5
model_paths = []
te_preds = []
scores2 = pd.DataFrame(columns=["month","train2.shape[0]","train2_mape","valid_mape","test2_mape","train2_rmse","valid_rmse","test2_rmse"])
month_list = [6,5,4,3,2,1,12,11,10,9,8]
train2 = for_train2[for_train2.month.isin(month_list)].reset_index(drop=True)
test2 = for_test2[for_test2.month==7].reset_index(drop=True)

features1 = ["year","month","day","time","minute","id","pvrate","id_lat","id_lng"] + [f"preal-30_{unique_id[i]}" for i in range(len(unique_id))] + [f"ppred_{unique_id[i]}" for i in range(len(unique_id))]
target = ["nv2"]

params = {
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'objective': 'regression',
    'device': 'gpu' # GPU!
}

kf = StratifiedKFold(n_splits=folds, shuffle=True,random_state=81)
for fold,(tr_idx, va_idx) in enumerate(kf.split(train2,train2["id"])):
  lgb_results = []

  train2_set = lgb.Dataset(train2.loc[train2.index.isin(tr_idx),features1],train2.loc[train2.index.isin(tr_idx),target])
  val_set = lgb.Dataset(train2.loc[train2.index.isin(va_idx),features1],train2.loc[train2.index.isin(va_idx),target])
  # train2 and evaluate
  lgb_result = {} 
  model = lgb.train(
      params, 
      train2_set, 
      num_boost_round = 100000, # 10000 
      early_stopping_rounds = 100, 
      valid_sets = [train2_set, val_set], 
      verbose_eval = 1000,
      evals_result = lgb_result,
  )
  lgb_results.append(lgb_result)

  model_path = f"./output/multi/multi_lgbm_{fold}.pkl"

  model_paths.append(model_path)
  joblib.dump(model, model_path)
  tt = joblib.load(model_path)
  #tr_pred = tt.predict(train2.loc[train2.index.isin(tr_idx),features1])
  #val_pred = tt.predict(train2.loc[train2.index.isin(va_idx),features1])

  train2.loc[train2.index.isin(va_idx),"pred"] = tt.predict(train2.loc[train2.index.isin(va_idx),features1])
  te_preds.append(tt.predict(test2[features1]))
test2["pred"] = np.mean(np.array(te_preds),axis=0)
# Out:
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 50832
# [LightGBM] [Info] Number of data points in the train set: 536025, number of used features: 207
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 207 dense feature groups (106.33 MB) transferred to GPU in 0.183937 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.363154
# Training until validation scores don't improve for 100 rounds
# [1000]	training's rmse: 0.0479641	valid_1's rmse: 0.0519069
# [2000]	training's rmse: 0.0399326	valid_1's rmse: 0.0465442
# [3000]	training's rmse: 0.0354213	valid_1's rmse: 0.0441618
# [4000]	training's rmse: 0.0322234	valid_1's rmse: 0.042747
# [5000]	training's rmse: 0.0296932	valid_1's rmse: 0.0417276
# [6000]	training's rmse: 0.0274869	valid_1's rmse: 0.0410055
# [7000]	training's rmse: 0.0257313	valid_1's rmse: 0.04048
# [8000]	training's rmse: 0.0242016	valid_1's rmse: 0.0400647
# [9000]	training's rmse: 0.0227981	valid_1's rmse: 0.0396813
# [10000]	training's rmse: 0.0216199	valid_1's rmse: 0.0393982
# [11000]	training's rmse: 0.0205768	valid_1's rmse: 0.0391601
# [12000]	training's rmse: 0.0196174	valid_1's rmse: 0.0389609
# [13000]	training's rmse: 0.0186734	valid_1's rmse: 0.0387546
# [14000]	training's rmse: 0.0177853	valid_1's rmse: 0.0385697
# [15000]	training's rmse: 0.0170589	valid_1's rmse: 0.0384447
# [16000]	training's rmse: 0.0163593	valid_1's rmse: 0.0383259
# [17000]	training's rmse: 0.0156866	valid_1's rmse: 0.0382262
# [18000]	training's rmse: 0.0150816	valid_1's rmse: 0.0381364
# [19000]	training's rmse: 0.0145232	valid_1's rmse: 0.0380648
# [20000]	training's rmse: 0.0140057	valid_1's rmse: 0.0380005
# [21000]	training's rmse: 0.0135063	valid_1's rmse: 0.0379335
# [22000]	training's rmse: 0.0129974	valid_1's rmse: 0.0378655
# [23000]	training's rmse: 0.0125618	valid_1's rmse: 0.0378067
# [24000]	training's rmse: 0.0121336	valid_1's rmse: 0.0377612
# [25000]	training's rmse: 0.0117244	valid_1's rmse: 0.0377145
# [26000]	training's rmse: 0.0113235	valid_1's rmse: 0.0376691
# [27000]	training's rmse: 0.010969	valid_1's rmse: 0.0376358
# [28000]	training's rmse: 0.0106326	valid_1's rmse: 0.037604
# [29000]	training's rmse: 0.0103087	valid_1's rmse: 0.0375764
# [30000]	training's rmse: 0.0100098	valid_1's rmse: 0.0375493
# [31000]	training's rmse: 0.00969745	valid_1's rmse: 0.0375218
# [32000]	training's rmse: 0.00940122	valid_1's rmse: 0.0374951
# [33000]	training's rmse: 0.00911403	valid_1's rmse: 0.0374732
# [34000]	training's rmse: 0.00886144	valid_1's rmse: 0.0374486
# [35000]	training's rmse: 0.00861846	valid_1's rmse: 0.0374313
# [36000]	training's rmse: 0.00837412	valid_1's rmse: 0.0374181
# [37000]	training's rmse: 0.00814928	valid_1's rmse: 0.0374003
# [38000]	training's rmse: 0.00790903	valid_1's rmse: 0.0373821
# Early stopping, best iteration is:
# [38589]	training's rmse: 0.00777773	valid_1's rmse: 0.0373704
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 50832
# [LightGBM] [Info] Number of data points in the train set: 536025, number of used features: 207
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 207 dense feature groups (106.33 MB) transferred to GPU in 0.063718 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.362949
# Training until validation scores don't improve for 100 rounds
# [1000]	training's rmse: 0.0475368	valid_1's rmse: 0.0517427
# [2000]	training's rmse: 0.0401671	valid_1's rmse: 0.0469505
# [3000]	training's rmse: 0.0355022	valid_1's rmse: 0.0445065
# [4000]	training's rmse: 0.0323022	valid_1's rmse: 0.0430981
# [5000]	training's rmse: 0.0297822	valid_1's rmse: 0.0421369
# [6000]	training's rmse: 0.0276981	valid_1's rmse: 0.0414597
# [7000]	training's rmse: 0.0258415	valid_1's rmse: 0.0408694
# [8000]	training's rmse: 0.0242711	valid_1's rmse: 0.0404268
# [9000]	training's rmse: 0.022903	valid_1's rmse: 0.0401006
# [10000]	training's rmse: 0.0217034	valid_1's rmse: 0.0398493
# [11000]	training's rmse: 0.0206244	valid_1's rmse: 0.0396159
# [12000]	training's rmse: 0.0196456	valid_1's rmse: 0.0394077
# [13000]	training's rmse: 0.0186918	valid_1's rmse: 0.0392195
# [14000]	training's rmse: 0.0179216	valid_1's rmse: 0.0390809
# [15000]	training's rmse: 0.0171492	valid_1's rmse: 0.0389424
# [16000]	training's rmse: 0.0163901	valid_1's rmse: 0.0388226
# [17000]	training's rmse: 0.0157019	valid_1's rmse: 0.0387033
# [18000]	training's rmse: 0.0150779	valid_1's rmse: 0.0386022
# [19000]	training's rmse: 0.0144896	valid_1's rmse: 0.0385026
# [20000]	training's rmse: 0.0139409	valid_1's rmse: 0.0384242
# [21000]	training's rmse: 0.0134438	valid_1's rmse: 0.0383506
# [22000]	training's rmse: 0.012985	valid_1's rmse: 0.0382935
# [23000]	training's rmse: 0.0125157	valid_1's rmse: 0.0382418
# [24000]	training's rmse: 0.0121082	valid_1's rmse: 0.0381958
# [25000]	training's rmse: 0.0117122	valid_1's rmse: 0.0381533
# [26000]	training's rmse: 0.0113193	valid_1's rmse: 0.038101
# [27000]	training's rmse: 0.0109538	valid_1's rmse: 0.0380654
# [28000]	training's rmse: 0.0106152	valid_1's rmse: 0.0380225
# [29000]	training's rmse: 0.0102967	valid_1's rmse: 0.0379879
# [30000]	training's rmse: 0.00999621	valid_1's rmse: 0.0379599
# [31000]	training's rmse: 0.00969991	valid_1's rmse: 0.0379332
# [32000]	training's rmse: 0.0094047	valid_1's rmse: 0.0379077
# [33000]	training's rmse: 0.00912292	valid_1's rmse: 0.037889
# [34000]	training's rmse: 0.00884276	valid_1's rmse: 0.0378613
# [35000]	training's rmse: 0.00859083	valid_1's rmse: 0.0378385
# [36000]	training's rmse: 0.00836054	valid_1's rmse: 0.0378197
# [37000]	training's rmse: 0.0081296	valid_1's rmse: 0.0378018
# [38000]	training's rmse: 0.00791981	valid_1's rmse: 0.0377822
# [39000]	training's rmse: 0.00772068	valid_1's rmse: 0.0377669
# [40000]	training's rmse: 0.00751799	valid_1's rmse: 0.0377496
# [41000]	training's rmse: 0.00732183	valid_1's rmse: 0.0377317
# [42000]	training's rmse: 0.00711616	valid_1's rmse: 0.0377141
# [43000]	training's rmse: 0.00693614	valid_1's rmse: 0.0377025
# [44000]	training's rmse: 0.00675661	valid_1's rmse: 0.0376925
# Early stopping, best iteration is:
# [44128]	training's rmse: 0.00673421	valid_1's rmse: 0.0376909
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 50832
# [LightGBM] [Info] Number of data points in the train set: 536026, number of used features: 207
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 207 dense feature groups (106.33 MB) transferred to GPU in 0.065068 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.363421
# Training until validation scores don't improve for 100 rounds
# [1000]	training's rmse: 0.0480957	valid_1's rmse: 0.0514481
# [2000]	training's rmse: 0.0400788	valid_1's rmse: 0.0460518
# [3000]	training's rmse: 0.0355595	valid_1's rmse: 0.0437057
# [4000]	training's rmse: 0.0322429	valid_1's rmse: 0.0422419
# [5000]	training's rmse: 0.0296831	valid_1's rmse: 0.0412187
# [6000]	training's rmse: 0.0276225	valid_1's rmse: 0.0404795
# [7000]	training's rmse: 0.0258433	valid_1's rmse: 0.0399572
# [8000]	training's rmse: 0.0242698	valid_1's rmse: 0.0395262
# [9000]	training's rmse: 0.0228766	valid_1's rmse: 0.0391258
# [10000]	training's rmse: 0.0216672	valid_1's rmse: 0.0388277
# [11000]	training's rmse: 0.0205438	valid_1's rmse: 0.0385695
# [12000]	training's rmse: 0.0195464	valid_1's rmse: 0.0383736
# [13000]	training's rmse: 0.0187057	valid_1's rmse: 0.0382195
# [14000]	training's rmse: 0.0178561	valid_1's rmse: 0.0380731
# [15000]	training's rmse: 0.0170462	valid_1's rmse: 0.0379304
# [16000]	training's rmse: 0.0162996	valid_1's rmse: 0.0377931
# [17000]	training's rmse: 0.0156365	valid_1's rmse: 0.0376781
# [18000]	training's rmse: 0.0150007	valid_1's rmse: 0.0375872
# [19000]	training's rmse: 0.0144555	valid_1's rmse: 0.0375029
# [20000]	training's rmse: 0.0139564	valid_1's rmse: 0.0374363
# [21000]	training's rmse: 0.0134517	valid_1's rmse: 0.037369
# [22000]	training's rmse: 0.0129921	valid_1's rmse: 0.0373206
# [23000]	training's rmse: 0.0125344	valid_1's rmse: 0.0372582
# [24000]	training's rmse: 0.0120829	valid_1's rmse: 0.0372079
# [25000]	training's rmse: 0.011686	valid_1's rmse: 0.0371622
# [26000]	training's rmse: 0.0113028	valid_1's rmse: 0.0371217
# [27000]	training's rmse: 0.0109408	valid_1's rmse: 0.0370781
# [28000]	training's rmse: 0.0105936	valid_1's rmse: 0.0370471
# [29000]	training's rmse: 0.010273	valid_1's rmse: 0.0370139
# [30000]	training's rmse: 0.00995128	valid_1's rmse: 0.0369883
# [31000]	training's rmse: 0.00965712	valid_1's rmse: 0.0369622
# [32000]	training's rmse: 0.0093729	valid_1's rmse: 0.0369286
# [33000]	training's rmse: 0.00910657	valid_1's rmse: 0.0369047
# [34000]	training's rmse: 0.00885077	valid_1's rmse: 0.0368788
# [35000]	training's rmse: 0.00859478	valid_1's rmse: 0.0368572
# [36000]	training's rmse: 0.0083497	valid_1's rmse: 0.0368373
# [37000]	training's rmse: 0.00812582	valid_1's rmse: 0.0368214
# [38000]	training's rmse: 0.0079079	valid_1's rmse: 0.0368033
# [39000]	training's rmse: 0.0076901	valid_1's rmse: 0.0367883
# [40000]	training's rmse: 0.00746675	valid_1's rmse: 0.0367704
# [41000]	training's rmse: 0.00726273	valid_1's rmse: 0.0367579
# [42000]	training's rmse: 0.00707652	valid_1's rmse: 0.0367432
# [43000]	training's rmse: 0.00689359	valid_1's rmse: 0.036731
# [44000]	training's rmse: 0.00671668	valid_1's rmse: 0.0367167
# [45000]	training's rmse: 0.00655238	valid_1's rmse: 0.036707
# [46000]	training's rmse: 0.00638071	valid_1's rmse: 0.0366978
# [47000]	training's rmse: 0.00622533	valid_1's rmse: 0.0366873
# Early stopping, best iteration is:
# [47321]	training's rmse: 0.00617982	valid_1's rmse: 0.0366832
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 50832
# [LightGBM] [Info] Number of data points in the train set: 536026, number of used features: 207
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 207 dense feature groups (106.33 MB) transferred to GPU in 0.064874 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.363267
# Training until validation scores don't improve for 100 rounds
# [1000]	training's rmse: 0.0478074	valid_1's rmse: 0.0518775
# [2000]	training's rmse: 0.0402369	valid_1's rmse: 0.0469028
# [3000]	training's rmse: 0.0355692	valid_1's rmse: 0.0443421
# [4000]	training's rmse: 0.0322333	valid_1's rmse: 0.0428539
# [5000]	training's rmse: 0.0297898	valid_1's rmse: 0.0418951
# [6000]	training's rmse: 0.0276003	valid_1's rmse: 0.0411627
# [7000]	training's rmse: 0.0258594	valid_1's rmse: 0.0406816
# [8000]	training's rmse: 0.0243138	valid_1's rmse: 0.0402938
# [9000]	training's rmse: 0.0229821	valid_1's rmse: 0.0399319
# [10000]	training's rmse: 0.021757	valid_1's rmse: 0.0396518
# [11000]	training's rmse: 0.0206445	valid_1's rmse: 0.0393981
# [12000]	training's rmse: 0.0196524	valid_1's rmse: 0.0391988
# [13000]	training's rmse: 0.0187421	valid_1's rmse: 0.0390358
# [14000]	training's rmse: 0.017915	valid_1's rmse: 0.0388892
# [15000]	training's rmse: 0.0171539	valid_1's rmse: 0.0387618
# [16000]	training's rmse: 0.0164338	valid_1's rmse: 0.0386564
# [17000]	training's rmse: 0.0157364	valid_1's rmse: 0.0385564
# [18000]	training's rmse: 0.0151077	valid_1's rmse: 0.0384611
# [19000]	training's rmse: 0.0145299	valid_1's rmse: 0.0383934
# [20000]	training's rmse: 0.0139922	valid_1's rmse: 0.0383235
# [21000]	training's rmse: 0.0134959	valid_1's rmse: 0.0382512
# [22000]	training's rmse: 0.0130204	valid_1's rmse: 0.0381873
# [23000]	training's rmse: 0.0125795	valid_1's rmse: 0.0381332
# [24000]	training's rmse: 0.0121517	valid_1's rmse: 0.0380823
# [25000]	training's rmse: 0.0117433	valid_1's rmse: 0.0380396
# [26000]	training's rmse: 0.0113594	valid_1's rmse: 0.0380021
# [27000]	training's rmse: 0.0109736	valid_1's rmse: 0.0379608
# [28000]	training's rmse: 0.010643	valid_1's rmse: 0.0379317
# [29000]	training's rmse: 0.0103231	valid_1's rmse: 0.0379019
# [30000]	training's rmse: 0.00999161	valid_1's rmse: 0.0378694
# [31000]	training's rmse: 0.00969041	valid_1's rmse: 0.0378422
# [32000]	training's rmse: 0.00939827	valid_1's rmse: 0.0378146
# [33000]	training's rmse: 0.0091159	valid_1's rmse: 0.0377876
# [34000]	training's rmse: 0.00886171	valid_1's rmse: 0.0377675
# [35000]	training's rmse: 0.00861538	valid_1's rmse: 0.0377538
# Early stopping, best iteration is:
# [35125]	training's rmse: 0.00858485	valid_1's rmse: 0.0377507
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 50832
# [LightGBM] [Info] Number of data points in the train set: 536026, number of used features: 207
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 207 dense feature groups (106.33 MB) transferred to GPU in 0.065026 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.362898
# Training until validation scores don't improve for 100 rounds
# [1000]	training's rmse: 0.0477653	valid_1's rmse: 0.0513243
# [2000]	training's rmse: 0.0403559	valid_1's rmse: 0.0463907
# [3000]	training's rmse: 0.0356068	valid_1's rmse: 0.0438678
# [4000]	training's rmse: 0.032242	valid_1's rmse: 0.0423758
# [5000]	training's rmse: 0.0297966	valid_1's rmse: 0.0414432
# [6000]	training's rmse: 0.0277157	valid_1's rmse: 0.0407505
# [7000]	training's rmse: 0.0258863	valid_1's rmse: 0.0401935
# [8000]	training's rmse: 0.0243475	valid_1's rmse: 0.0397564
# [9000]	training's rmse: 0.0229604	valid_1's rmse: 0.0394048
# [10000]	training's rmse: 0.0217465	valid_1's rmse: 0.0391151
# [11000]	training's rmse: 0.0206972	valid_1's rmse: 0.0388953
# [12000]	training's rmse: 0.0196824	valid_1's rmse: 0.0386729
# [13000]	training's rmse: 0.0187756	valid_1's rmse: 0.0384844
# [14000]	training's rmse: 0.0179168	valid_1's rmse: 0.0383363
# [15000]	training's rmse: 0.0171781	valid_1's rmse: 0.0382162
# [16000]	training's rmse: 0.0164412	valid_1's rmse: 0.0380884
# [17000]	training's rmse: 0.0157743	valid_1's rmse: 0.0379865
# [18000]	training's rmse: 0.0151504	valid_1's rmse: 0.0378915
# [19000]	training's rmse: 0.0145336	valid_1's rmse: 0.037801
# [20000]	training's rmse: 0.0140047	valid_1's rmse: 0.0377281
# [21000]	training's rmse: 0.0135009	valid_1's rmse: 0.0376608
# [22000]	training's rmse: 0.0130149	valid_1's rmse: 0.0375985
# [23000]	training's rmse: 0.0125656	valid_1's rmse: 0.0375497
# [24000]	training's rmse: 0.0121374	valid_1's rmse: 0.0375069
# [25000]	training's rmse: 0.0116977	valid_1's rmse: 0.037461
# [26000]	training's rmse: 0.0113085	valid_1's rmse: 0.0374182
# [27000]	training's rmse: 0.0109282	valid_1's rmse: 0.0373765
# [28000]	training's rmse: 0.0105764	valid_1's rmse: 0.0373371
# [29000]	training's rmse: 0.0102552	valid_1's rmse: 0.0373066
# [30000]	training's rmse: 0.00996454	valid_1's rmse: 0.0372771
# [31000]	training's rmse: 0.00968891	valid_1's rmse: 0.0372576
# [32000]	training's rmse: 0.00940527	valid_1's rmse: 0.0372292
# [33000]	training's rmse: 0.00913272	valid_1's rmse: 0.0372052
# [34000]	training's rmse: 0.00886437	valid_1's rmse: 0.0371805
# [35000]	training's rmse: 0.00860368	valid_1's rmse: 0.0371539
# [36000]	training's rmse: 0.00836304	valid_1's rmse: 0.0371332
# [37000]	training's rmse: 0.00813384	valid_1's rmse: 0.0371189
# [38000]	training's rmse: 0.00791645	valid_1's rmse: 0.0371026
# [39000]	training's rmse: 0.00769375	valid_1's rmse: 0.0370863
# [40000]	training's rmse: 0.00748649	valid_1's rmse: 0.0370699
# [41000]	training's rmse: 0.00728268	valid_1's rmse: 0.0370584
# Early stopping, best iteration is:
# [41486]	training's rmse: 0.00718178	valid_1's rmse: 0.0370524

# %%
scores2= scores2.append({"month":month_list,"train2.shape[0]":train2.shape[0],
              "train2_mape":(np.abs((train2.loc[train2.nv2!=0,"pred"] - train2.loc[train2.nv2!=0,"nv2"])/train2.loc[train2.nv2!=0,"nv2"])).mean(),
             # "valid_mape":(np.abs((valid.loc[valid.nv2!=0,"pred"] - valid.loc[valid.nv2!=0,"nv2"])/valid.loc[valid.nv2!=0,"nv2"])).mean(),
              "test2_mape":(np.abs((test2.loc[test2.nv2!=0,"pred"] - test2.loc[test2.nv2!=0,"nv2"])/test2.loc[test2.nv2!=0,"nv2"])).mean(),
              "train2_rmse":np.sqrt(mean_squared_error(train2["nv2"], train2["pred"])),
             # "valid_rmse":np.sqrt(mean_squared_error(valid["nv2"], valid["pred"])),
              "test2_rmse":np.sqrt(mean_squared_error(test2["nv2"], test2["pred"]))}
            ,ignore_index=True)

train2["env2"] = train2["env"] / train2["observed_max"]
#valid["env2"] = valid["env"] / valid["observed_max"]
test2["env2"] = test2["env"] / test2["observed_max"]

test2["observed"] = test2["nv2"]*test2["observed_max"]
test2["fluctuation"] = np.abs((test2["observed"] - test2["preal-30"])/test2["observed_max"])
test2_result = pd.DataFrame(columns=["id","rmse","mape","mae_per","rmse_op","mape_op","nrmse","nmae","r2","mae_per_op","nrmse_op","nmae_op","r2_op","fluctuation","observed_max"])
for id,group in test2.groupby("id"):
  mape = (np.abs((group.loc[group.nv2!=0,"pred"] - group.loc[group.nv2!=0,"nv2"])/group.loc[group.nv2!=0,"nv2"])).mean()
  rmse = np.sqrt(mean_squared_error(group["nv2"], group["pred"]))
  mae_per = np.abs(group["pred"] - group["nv2"]).mean()
  nrmse = np.sqrt(np.mean(((group.pred-group.nv2)/group.nv2.max())**(2))) ##論文　Spatio-Temporal Graph Neural Networks for Multi-Site PV Power Forecasting
  nmae = np.abs(group.pred-group.nv2).sum()/group.nv2.sum() ##論文　Spatio-Temporal Graph Neural Networks for Multi-Site PV Power Forecasting
  r2 = r2_score(group["nv2"], group["pred"])

  mape_op = (np.abs((group.loc[group.nv2!=0,"env2"] - group.loc[group.nv2!=0,"nv2"])/group.loc[group.nv2!=0,"nv2"])).mean()
  rmse_op = np.sqrt(mean_squared_error(group["nv2"], group["env2"]))
  mae_per_op = np.abs(group["pred"] - group["env2"]).mean()
  nrmse_op = np.sqrt(np.mean(((group.env2-group.nv2)/group.nv2.max())**(2)))
  nmae_op = np.abs(group.env2-group.nv2).sum()/group.nv2.sum()
  r2_op = r2_score(group["env2"], group["pred"])

  fluctuation = group["fluctuation"].mean()
  observed_max = group["observed_max"].iloc[0]

  test2_result = test2_result.append({"id":id,"rmse":rmse,"mape":mape,"mae_per":mae_per,"nrmse":nrmse,"nmae":nmae,"r2":r2,"rmse_op":rmse_op,"mape_op":mape_op,"mae_per_op":mae_per_op,"nrmse_op":nrmse_op,\
                                    "nmae_op":nmae_op,"r2_op":r2_op,"fluctuation":fluctuation,"observed_max":observed_max,"observed_max_test2":group.nv2.max()},ignore_index=True)

df_test2 = pd.merge(df_missing,test2_result,on="id")
df_test2 = df_test2[df_test2.missing_percent_test==0]

scores2.to_csv("./output/multi/scores_.csv",index=False)
df_test2.to_csv("./output/multi/df_test2_.csv",index=False)
test2.to_csv("./output/multi/test2_.csv",index=False)
train2.to_csv("./output/multi/train2_.csv",index=False)

# %%
scores2
# Out:
#                                   month train2.shape[0]  train2_mape  \
# 0  [6, 5, 4, 3, 2, 1, 12, 11, 10, 9, 8]          670032     0.098719
#
#    valid_mape  test2_mape  train2_rmse  valid_rmse  test2_rmse
# 0         NaN    0.222975     0.037312         NaN    0.084907
